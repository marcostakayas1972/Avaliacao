# %%
# %sql
select * from workspace.silver.tb_pedidos_itens A
left join workspace.silver.tb_pedidos_cabecalho B using(order_id)
left join workspace.silver.dim_produto C on C.product_id = A.product_code
